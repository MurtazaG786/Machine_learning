# %% [markdown]
# <a href="https://colab.research.google.com/github/MurtazaG786/Machine_learning/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
printg()
# Out:
# hello

# %%
def printg():
  print("hello")
